# %% [markdown]
# # Subject selction

# %%
import pandas as pd

# %%
df = pd.read_csv('hcp_unrestricted_data.csv')
dfr = pd.read_csv('hcp_restricted_data.csv')

# %% [markdown]
# ### make sure we don't look at multiple subjects from the same family to avoid Oxford mafia

# %%
assert len(sum(dfr.groupby(['Mother_ID', 'Father_ID']).groups.values(), [])) == 970

# %%
unique_index = [x[0] for x in dfr.groupby(['Mother_ID', 'Father_ID']).groups.values()]

# %% [markdown]
# ### which are the subjects for which freesurfe outputs are missing on AWS?

# %%
not_related_df = df.ix[unique_index]
not_related_df_final_subjects = not_related_df[not_related_df.MEG_AnyData]
freesurfer_missing = not_related_df_final_subjects.Subject[not_related_df_final_subjects.Release == 'S900'].astype(str).tolist()

# %%
not_related_df_final_subjects
# Out:
#      Subject Release Acquisition Gender    Age 3T_Full_MR_Compl  T1_Count  \
# 410   192641    MEG2         Q07      F  31-35             True         2
# 597   358144    S900         Q10      F  26-30             True         2
# 231   151526      Q3         Q03      M  26-30             True         1
# 376   182840      Q2         Q03      M  31-35            False         2
# 27    105923    MEG2         Q07      F  31-35             True         2
# 245   154532    S900          Q9      M  26-30             True         2
# 813   725751    S900         Q05      M  26-30             True         1
# 337   174841    S900          Q9      M  22-25             True         2
# 321   172029    S500         Q06      M  26-30             True         2
# 77    116524    S500         Q05      M  26-30             True         1
# 396   189349    S500         Q05      F  26-30             True         2
# 419   195041    S500         Q07      F  31-35             True         2
# 400   191033    S500         Q06      F  26-30             True         2
# 263   158136    S500         Q04      M  31-35             True         2
# 41    108323    S500         Q04      F  26-30             True         2
# 59    112920    S900         Q10      M  31-35             True         2
# 549   287248    MEG2         Q08      F  26-30             True         1
# 293   164636    S900          Q9      M  22-25             True         2
# 115   125525      Q1         Q01      F  31-35             True         1
# 371   181232    S500         Q04      F  26-30             True         2
# 19    104012    MEG2         Q07      F  26-30             True         1
# 361   179245    S900         Q10      F  31-35             True         2
# 513   221319      Q2         Q03      F  26-30             True         1
# 31    106521    S500         Q06      F  26-30             True         1
# 149   133019    S500         Q06      F  26-30             True         2
# 203   146129    MEG2         Q08      M  22-25             True         2
# 14    102816      Q3         Q03      F  26-30             True         1
# 44    109123    S500         Q06      M  31-35             True         2
# 63    113922    S500         Q04      M  31-35             True         2
# 78    116726    S900         Q08      M  26-30             True         2
# 254   156334    MEG2         Q03      F  26-30             True         2
# 2     100307      Q1         Q01      F  26-30             True         1
# 381   185442    S500         Q07      M  22-25             True         2
# 497   212318      Q2         Q02      F  31-35             True         2
# 221   149741    S500         Q05      M  26-30             True         1
#
#      T2_Count  3T_RS-fMRI_Count  3T_RS-fMRI_PctCompl    ...     NEORAW_60  \
# 410         2                 4                  100    ...             A
# 597         1                 4                  100    ...             A
# 231         1                 4                  100    ...            SA
# 376         2                 4                  100    ...             N
# 27          2                 4                  100    ...             A
# 245         2                 4                  100    ...             A
# 813         1                 4                  100    ...             A
# 337         2                 4                  100    ...            SA
# 321         2                 4                  100    ...            SA
# 77          1                 4                  100    ...            SA
# 396         1                 4                  100    ...            SA
# 419         2                 4                  100    ...             A
# 400         2                 4                  100    ...            SA
# 263         2                 4                  100    ...             N
# 41          2                 4                  100    ...             A
# 59          2                 4                  100    ...             A
# 549         2                 4                  100    ...             A
# 293         1                 4                  100    ...             D
# 115         1                 4                  100    ...            SA
# 371         2                 4                  100    ...            SA
# 19          2                 4                  100    ...            SA
# 361         1                 4                  100    ...             A
# 513         1                 4                  100    ...             A
# 31          1                 4                  100    ...             D
# 149         1                 4                  100    ...             A
# 203         2                 4                  100    ...            SA
# 14          1                 4                  100    ...            SA
# 44          1                 4                  100    ...             N
# 63          1                 4                  100    ...             A
# 78          1                 4                  100    ...            SA
# 254         2                 4                  100    ...             A
# 2           1                 4                  100    ...             A
# 381         2                 4                  100    ...            SA
# 497         2                 4                  100    ...            SA
# 221         1                 4                  100    ...             A
#
#      Noise_Comp  Odor_Unadj  Odor_AgeAdj  PainInterf_Tscore  Taste_Unadj  \
# 410         3.6      122.25       111.41               38.6        96.87
# 597         4.4      108.79        98.04               38.6        86.03
# 231         3.6      108.79        97.19               60.3        89.68
# 376         5.2      122.25       111.41               59.1       101.63
# 27          5.2      122.25       111.41               38.6        97.26
# 245         3.6       96.87        77.12               57.7       109.85
# 813         6.0      108.79        97.19               44.5       134.65
# 337         5.2      108.79        97.19               38.6        90.63
# 321         5.2      108.79        97.19               52.8        77.47
# 77          6.0      122.25       110.45               64.2       106.39
# 396         5.2       96.87        77.12               48.6        98.31
# 419         5.2      122.25       111.41               52.6       113.65
# 400         2.8      108.79        97.19               56.0        99.67
# 263         6.0      122.25       111.41               38.6       117.59
# 41          3.6      101.12        86.45               51.1        78.02
# 59          3.6      101.12        87.11               38.6       103.37
# 549         2.8      101.12        87.11               48.7        99.67
# 293         4.4      108.79        97.19               46.6       113.65
# 115         5.2      108.79        98.04               38.6        71.69
# 371         3.6      122.25       110.45               38.6        96.38
# 19          6.0      122.25       110.45               50.1        78.02
# 361         5.2      108.79        98.04               38.6        70.31
# 513         6.0      108.79        97.19               61.5       116.22
# 31          2.8      122.25       110.45               38.6        88.02
# 149         6.0      108.79        97.19               38.6       116.75
# 203       -99.0      108.79        97.19               52.2       108.73
# 14          5.2      122.25       111.41               52.6        98.31
# 44          5.2      101.12        87.11               57.3       103.37
# 63          5.2      122.25       111.41               52.6        95.36
# 78          6.0      122.25       110.45               51.1        73.86
# 254         4.4      101.12        86.45               50.1       118.37
# 2           3.6      101.12        86.45               38.6        71.69
# 381         6.0      122.25       110.45               38.6        83.23
# 497         3.6      108.79        98.04               56.2        78.02
# 221         6.0      108.79        97.19               38.6        79.67
#
#      Taste_AgeAdj  Mars_Log_Score  Mars_Errs Mars_Final
# 410         95.48            1.80          2       1.72
# 597         84.40            1.92          1       1.88
# 231         88.45            1.76          1       1.72
# 376         99.26            1.76          1       1.72
# 27          96.41            1.88          1       1.84
# 245        109.71            1.80          0       1.80
# 813        131.38            1.80          0       1.80
# 337         88.99            1.80          0       1.80
# 321         76.79            1.80          2       1.72
# 77         104.39            1.68          0       1.68
# 396         99.06            1.80          0       1.80
# 419        113.24            1.72          1       1.68
# 400        100.24            1.92          1       1.88
# 263        117.07            1.76          1       1.72
# 41          77.40            1.80          2       1.72
# 59         100.40            1.80          0       1.80
# 549         98.45            1.84          3       1.72
# 293        113.94            1.80          0       1.80
# 115         69.80            1.76          1       1.72
# 371         96.35            1.80          1       1.76
# 19          77.40            1.80          0       1.80
# 361         67.90            1.80          0       1.80
# 513        116.29            1.76          1       1.72
# 31          87.70            1.80          0       1.80
# 149        117.02            1.80          2       1.72
# 203        108.00            1.80          2       1.72
# 14          97.68            1.72          1       1.68
# 44         100.40            1.84          0       1.84
# 63          93.48            1.80          0       1.80
# 78          72.70            1.80          0       1.80
# 254        118.42            1.84          1       1.80
# 2           71.76            1.76          0       1.76
# 381         83.12            1.92          4       1.76
# 497         76.10            1.76         17       1.08
# 221         78.91            1.80          0       1.80
#
# [35 rows x 550 columns]

# %%
print('|'.join(freesurfer_missing))
# Out:
# 358144|154532|725751|174841|112920|164636|179245|116726

# %%
missing_fsurfer = pd.DataFrame()
missing_fsurfer['SubjectId'] = not_related_df_final_subjects.Subject[not_related_df_final_subjects.Release == 'S900']
missing_fsurfer['CodedId'] = list(range(len(missing_fsurfer)))
missing_fsurfer.to_csv('missing_freesurfer_s900_unrelated.csv', index=False)
not_related_df_final_subjects.to_csv('unrelated_MEG_subjects.csv')
